# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime
from datetime import date, timedelta
import datetime
import matplotlib.dates as mdates
# %matplotlib inline
import pickle

# %% [markdown]
# https://healthdata.gov/dataset/COVID-19-Community-Profile-Report-County-Level/di4u-7yu6

# %% [markdown]
# https://healthdata.gov/api/views/di4u-7yu6/rows.csv?accessType=DOWNLOAD

# %%
df_hhs = pd.read_csv('https://healthdata.gov/api/views/di4u-7yu6/rows.csv?accessType=DOWNLOAD')

# %%
df_hhs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3294 entries, 0 to 3293
# Data columns (total 39 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   fips                                                         3294 non-null   int64
#  1   county                                                       3294 non-null   object
#  2   state                                                        3294 non-null   object
#  3   fema_region                                                  3291 non-null   float64
#  4   date                                                         3294 non-null   object
#  5   cases_last_7_days                                            3278 non-null   float64
#  6   cases_per_100k_last_7_days                                   3220 non-null   float64
# ...

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)

# %%
df_hhs[df_hhs.county == 'Bexar County, TX'].T
# Out:
#                                                                       2581
# fips                                                                 48029
# county                                                    Bexar County, TX
# state                                                                   TX
# fema_region                                                            6.0
# date                                                02/16/2022 12:00:00 AM
# cases_last_7_days                                                   7602.0
# cases_per_100k_last_7_days                                         379.426
# total_cases                                                       537769.0
# cases_pct_change_from_prev_week                                     -0.429
# deaths_last_7_days                                                   117.0
# deaths_per_100k_last_7_days                                           5.84
# ...

# %%
df_hhs[df_hhs.county == 'Harris County, TX'].T
# Out:
#                                                                       2667
# fips                                                                 48201
# county                                                   Harris County, TX
# state                                                                   TX
# fema_region                                                            6.0
# date                                                02/16/2022 12:00:00 AM
# cases_last_7_days                                                   8353.0
# cases_per_100k_last_7_days                                         177.221
# total_cases                                                       982475.0
# cases_pct_change_from_prev_week                                     -0.405
# deaths_last_7_days                                                   140.0
# deaths_per_100k_last_7_days                                           2.97
# ...

# %%
df_hhs.deaths_per_100k_last_7_days.max()
# Out:
# 293.255

# %%
df_hhs[df_hhs.deaths_per_100k_last_7_days == df_hhs.deaths_per_100k_last_7_days.max()].T
# Out:
#                                                                       1727
# fips                                                                 31091
# county                                                   Hooker County, NE
# state                                                                   NE
# fema_region                                                            7.0
# date                                                01/26/2022 12:00:00 AM
# cases_last_7_days                                                      4.0
# cases_per_100k_last_7_days                                          586.51
# total_cases                                                          106.0
# cases_pct_change_from_prev_week                                      0.333
# deaths_last_7_days                                                     2.0
# deaths_per_100k_last_7_days                                        293.255
# ...

# %%
df_hhs[df_hhs.county == 'Suffolk County, MA'].T
# Out:
#                                                                       1251
# fips                                                                 25025
# county                                                  Suffolk County, MA
# state                                                                   MA
# fema_region                                                            1.0
# date                                                01/26/2022 12:00:00 AM
# cases_last_7_days                                                   8189.0
# cases_per_100k_last_7_days                                         1018.65
# total_cases                                                       195110.0
# cases_pct_change_from_prev_week                                      -0.37
# deaths_last_7_days                                                    48.0
# deaths_per_100k_last_7_days                                          5.971
# ...

# %%
df_hhs[['county','pct_icu_beds_used_avg_last_7_days']].sort_values(by = 'pct_icu_beds_used_avg_last_7_days')
# Out:
#                                      county  pct_icu_beds_used_avg_last_7_days
# 2507                     Hawkins County, TN                              0.000
# 3181                     Lincoln County, WY                              0.000
# 1289                        Iron County, MI                              0.000
# 2137                      Morrow County, OH                              0.000
# 1774                        York County, NE                              0.000
# 1772                     Webster County, NE                              0.000
# 1771                       Wayne County, NE                              0.000
# 1768                    Thurston County, NE                              0.000
# 1755                  Richardson County, NE                              0.000
# 286                   Las Animas County, CO                              0.000
# 1749                     Perkins County, NE                              0.000
# ...
