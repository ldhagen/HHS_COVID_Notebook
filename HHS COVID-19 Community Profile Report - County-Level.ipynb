# %%
import pandas as pd
import matplotlib.pyplot as plt
import numpy as np
import datetime
from datetime import date, timedelta
import datetime
import matplotlib.dates as mdates
# %matplotlib inline
import pickle

# %% [markdown]
# https://healthdata.gov/dataset/COVID-19-Community-Profile-Report-County-Level/di4u-7yu6

# %%
df_hhs = pd.read_csv('https://healthdata.gov/api/views/di4u-7yu6/rows.csv?accessType=DOWNLOAD', parse_dates = ['date'])

# %%
df_hhs.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 3294 entries, 0 to 3293
# Data columns (total 39 columns):
#  #   Column                                                       Non-Null Count  Dtype
# ---  ------                                                       --------------  -----
#  0   fips                                                         3294 non-null   int64
#  1   county                                                       3294 non-null   object
#  2   state                                                        3294 non-null   object
#  3   fema_region                                                  3291 non-null   float64
#  4   date                                                         3294 non-null   datetime64[ns]
#  5   cases_last_7_days                                            3278 non-null   float64
#  6   cases_per_100k_last_7_days                                   3220 non-null   float64
#  7   total_cases                                                  3278 non-null   float64
#  8   cases_pct_change_from_prev_week                              3203 non-null   float64
#  9   deaths_last_7_days                                           3278 non-null   float64
#  10  deaths_per_100k_last_7_days                                  3220 non-null   float64
#  11  total_deaths                                                 3278 non-null   float64
#  12  deaths_pct_change_from_prev_week                             1658 non-null   float64
#  13  test_positivity_rate_last_7_days                             3246 non-null   float64
#  14  total_positive_tests_last_7_days                             3247 non-null   float64
#  15  total_tests_last_7_days                                      3247 non-null   float64
#  16  total_tests_per_100k_last_7_days                             3221 non-null   float64
#  17  test_positivity_rate_pct_change_from_prev_week               3235 non-null   float64
#  18  total_tests_pct_change_from_prev_week                        3249 non-null   float64
#  19  confirmed_covid_hosp_last_7_days                             2477 non-null   float64
#  20  confirmed_covid_hosp_per_100_beds_last_7_days                2453 non-null   float64
#  21  confirmed_covid_hosp_per_100_beds_pct_change_from_prev_week  1947 non-null   float64
#  22  suspected_covid_hosp_last_7_days                             2477 non-null   float64
#  23  suspected_covid_hosp_per_100_beds_last_7_days                2453 non-null   float64
#  24  suspected_covid_hosp_per_100_beds_pct_change_from_prev_week  946 non-null    float64
#  25  pct_inpatient_beds_used_avg_last_7_days                      2457 non-null   float64
#  26  pct_inpatient_beds_used_abs_change_from_prev_week            2456 non-null   float64
#  27  pct_inpatient_beds_used_covid_avg_last_7_days                2457 non-null   float64
#  28  pct_inpatient_beds_used_covid_abs_change_from_prev_week      2456 non-null   float64
#  29  pct_icu_beds_used_avg_last_7_days                            1559 non-null   float64
#  30  pct_icu_beds_used_abs_change_from_prev_week                  1551 non-null   float64
#  31  pct_icu_beds_used_covid_avg_last_7_days                      1559 non-null   float64
#  32  pct_icu_beds_used_covid_abs_change_from_prev_week            1551 non-null   float64
#  33  pct_vents_used_avg_last_7_days                               2342 non-null   float64
#  34  pct_vents_used_abs_change_from_prev_week                     2342 non-null   float64
#  35  pct_vents_used_covid_avg_last_7_days                         2342 non-null   float64
#  36  pct_vents_used_covid_abs_change_from_prev_week               2342 non-null   float64
#  37  pct_fully_vacc_total_pop                                     3194 non-null   float64
#  38  pct_fully_vacc_65_and_older                                  3194 non-null   float64
# dtypes: datetime64[ns](1), float64(35), int64(1), object(2)
# memory usage: 1003.8+ KB

# %%
df_hhs[df_hhs['county'] == 'Bexar County, TX']
# Out:
#        fips            county state  fema_region       date  \
# 2581  48029  Bexar County, TX    TX          6.0 2022-01-05
#
#       cases_last_7_days  cases_per_100k_last_7_days  total_cases  \
# 2581            22283.0                    1112.174     361426.0
#
#       cases_pct_change_from_prev_week  deaths_last_7_days  ...  \
# 2581                            3.512                17.0  ...
#
#       pct_icu_beds_used_avg_last_7_days  \
# 2581                               0.91
#
#       pct_icu_beds_used_abs_change_from_prev_week  \
# 2581                                        0.024
#
#       pct_icu_beds_used_covid_avg_last_7_days  \
# 2581                                    0.165
#
#       pct_icu_beds_used_covid_abs_change_from_prev_week  \
# 2581                                              0.034
#
#       pct_vents_used_avg_last_7_days  \
# 2581                           0.392
#
#       pct_vents_used_abs_change_from_prev_week  \
# 2581                                     0.027
#
#       pct_vents_used_covid_avg_last_7_days  \
# 2581                                 0.036
#
#       pct_vents_used_covid_abs_change_from_prev_week  \
# 2581                                           0.003
#
#       pct_fully_vacc_total_pop  pct_fully_vacc_65_and_older
# 2581                     0.652                        0.917
#
# [1 rows x 39 columns]

# %%
df_hhs.deaths_last_7_days.max()
# Out:
# 208.0

# %%
df_hhs[df_hhs.deaths_last_7_days > 100]
# Out:
#        fips               county state  fema_region       date  \
# 106    4013  Maricopa County, AZ    AZ          9.0 2022-01-05
# 624   17031      Cook County, IL    IL          5.0 2022-01-05
# 1884  36047     Kings County, NY    NY          2.0 2022-01-05
#
#       cases_last_7_days  cases_per_100k_last_7_days  total_cases  \
# 106             35072.0                     781.912     897529.0
# 624             74639.0                    1449.235     883180.0
# 1884            79740.0                    3114.962     524070.0
#
#       cases_pct_change_from_prev_week  deaths_last_7_days  ...  \
# 106                             1.170               208.0  ...
# 624                             0.269               171.0  ...
# 1884                            0.446               102.0  ...
#
#       pct_icu_beds_used_avg_last_7_days  \
# 106                               0.787
# 624                               0.730
# 1884                              0.825
#
#       pct_icu_beds_used_abs_change_from_prev_week  \
# 106                                         0.004
# 624                                         0.015
# 1884                                        0.036
#
#       pct_icu_beds_used_covid_avg_last_7_days  \
# 106                                     0.257
# 624                                     0.273
# 1884                                    0.340
#
#       pct_icu_beds_used_covid_abs_change_from_prev_week  \
# 106                                              -0.002
# 624                                               0.053
# 1884                                              0.158
#
#       pct_vents_used_avg_last_7_days  \
# 106                            0.461
# 624                            0.335
# 1884                           0.218
#
#       pct_vents_used_abs_change_from_prev_week  \
# 106                                      0.002
# 624                                      0.018
# 1884                                     0.022
#
#       pct_vents_used_covid_avg_last_7_days  \
# 106                                  0.152
# 624                                  0.089
# 1884                                 0.055
#
#       pct_vents_used_covid_abs_change_from_prev_week  \
# 106                                            0.000
# 624                                            0.021
# 1884                                           0.030
#
#       pct_fully_vacc_total_pop  pct_fully_vacc_65_and_older
# 106                      0.538                        0.825
# 624                      0.677                        0.834
# 1884                     0.667                        0.761
#
# [3 rows x 39 columns]
